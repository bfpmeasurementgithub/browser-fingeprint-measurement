# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import csv
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from matplotlib import gridspec


import csv
import pandas as pd
import sys
import time

# %%
'''
The file is like
signal,customer,id_type,browser,tel_isattack,start_ts,end_ts,
num_distinct_pid_not_null,num_ids,entropy,collision_ratio,
num_values,num_devices,division,num_device_with_multiple_values,
ratio_device_multiple_values,num_distinct

'''

# %%
file = open('./new_bfp.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
dic = {}
for raw in reader_lines:
    if raw[0] == 'signal':
        continue
    if float(raw[7]) == 0:
        continue
    if raw[1] not in dic:
        dic[raw[1]] =  [[[0 for k in range(2)] for i in range(4)] for j in range(2)]
    company = raw[1]
    if raw[4] == 'normal':
        types = 0
    else:
        types = 1
    if raw[5][-1] == '9':
        date = 0
    elif raw[5][-1] == '3':
        date = 1
    elif raw[5][-1] == '6':
        date = 2
    else:
        date = 3
    dic[company][types][date] = [float(raw[9]),float(raw[13]) ]

# %%
print(dic)

# %%
for ele in dic:
    print(ele,dic[ele])
    print('==================================================================')

# %%
val = 4
adv_entr = [[] for i in range(val)]
adv_div = [[] for i in range(val)]
ben_entr = [[] for i in range(val)]
ben_dic = [[] for i in range(val)]

for i in range(val):
    for ele in dic:
        ben_entr[i].append(dic[ele][0][i][0])
        ben_dic[i].append(dic[ele][0][i][1])
        adv_entr[i].append(dic[ele][1][i][0])
        adv_div[i].append(dic[ele][1][i][1])
print(adv_entr)
print(ben_entr)
print(adv_div)
print(ben_dic)

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['One Day', 'One Week', 'Two Week', 'One Month']
label_arr = []
normal_arr = []
attack_arr = []
for key in dic:
    label_arr.append(key)
    tem = []
    for ele in dic[key][0]:
        tem.append(ele[0])
    normal_arr.append(tem)
    tem = []
    for ele in dic[key][1]:
        tem.append(ele[0])
    attack_arr.append(tem)

    
print(normal_arr)
print(attack_arr)



x = np.arange(len(labels)) 

rects = [0 for i in range(2 * len(label_arr))]
fig, ax = plt.subplots()
for i in range(len(label_arr)):
    rects[i] = ax.plot(normal_arr[i])
    rects[len(label_arr) +  i] = ax.plot(attack_arr[i], linestyle = (0, (1, 1)))

ax.set_ylabel('Entorpy',fontsize = 16)
ax.set_xticks(x, labels,fontsize = 16)

fig.tight_layout()
plt.savefig('Entropy_time.eps',format='eps')

plt.show()

# %%
for ele

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['One Day', 'One Week', 'Two Week', 'One Month']
label_arr = []
normal_arr = []
attack_arr = []
for key in dic:
    label_arr.append(key)
    tem = []
    for ele in dic[key][0]:
        tem.append(ele[1])
    normal_arr.append(tem)
    tem = []
    for ele in dic[key][1]:
        tem.append(ele[1])
    attack_arr.append(tem)

x = np.arange(len(labels))  

rects = [0 for i in range(2 * len(label_arr))]
fig, ax = plt.subplots()
for i in range(len(label_arr)):
#     rects[i] = ax.plot(normal_arr[i], label=label_arr[i] + ' Benign')
#     rects[len(label_arr) +  i] = ax.plot(attack_arr[i], label=label_arr[i] + ' Adv',linestyle = (0, (1, 10)))
    rects[i] = ax.plot(normal_arr[i])
    rects[len(label_arr) +  i] = ax.plot(attack_arr[i], linestyle = (0, (1, 1)))

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Fingerprint per Device',fontsize = 16)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels,fontsize = 16)
# ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.savefig('Division_time.eps',format='eps')
plt.show()

# %%
file = open('./new_bfp_ua.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
dic = {}
for raw in reader_lines:
    if raw[0] == 'signal':
        continue
    if float(raw[7]) == 0:
        continue
#     print(raw[1])
    if raw[1] not in dic:
        dic[raw[1]] =  [[[0 for k in range(2)] for i in range(4)] for j in range(2)]
    company = raw[1]
    #normal, attack
    if raw[4] == 'normal':
        types = 0
    else:
        types = 1
    # date 1 day/ 1 week/ 2 week/ 1 month
#     print(raw[5],raw[5][-1])
    if raw[5][-1] == '9':
        date = 0
    elif raw[5][-1] == '3':
        date = 1
    elif raw[5][-1] == '6':
        date = 2
    else:
        date = 3
#     print(dat)
    dic[company][types][date] = [float(raw[9]),float(raw[13]) ]

# %%
print(dic)

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['One Day', 'One Week', 'Two Week', 'One Month']
label_arr = []
normal_arr = []
attack_arr = []
for key in dic:
    label_arr.append(key)
    tem = []
    for ele in dic[key][0]:
        tem.append(ele[0])
    normal_arr.append(tem)
    tem = []
    for ele in dic[key][1]:
        tem.append(ele[0])
    attack_arr.append(tem)
# print(normal_arr,attack_arr)
    
# men_means = [20, 34, 30, 35]
# women_means = [25, 32, 34, 20]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

rects = [0 for i in range(2 * len(label_arr))]
fig, ax = plt.subplots()
for i in range(len(label_arr)):
#     rects[i] = ax.plot(normal_arr[i], label=label_arr[i] + ' Benign')
#     rects[len(label_arr) +  i] = ax.plot(attack_arr[i], label=label_arr[i] + ' Adv',linestyle = (0, (1, 10)))
    rects[i] = ax.plot(normal_arr[i])
    rects[len(label_arr) +  i] = ax.plot(attack_arr[i], linestyle = (0, (1, 1)))
# rects[1] = ax.plot(men_means, label='Men')
# rects[2] = ax.plot(women_means, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Entorpy',fontsize = 16)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels,fontsize = 16)
# ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.savefig('Entropy_time_ua.eps',format='eps')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['One Day', 'One Week', 'Two Week', 'One Month']
label_arr = []
normal_arr = []
attack_arr = []
for key in dic:
    label_arr.append(key)
    tem = []
    for ele in dic[key][0]:
        tem.append(ele[1])
    normal_arr.append(tem)
    tem = []
    for ele in dic[key][1]:
        tem.append(ele[1])
    attack_arr.append(tem)
# print(normal_arr,attack_arr)
    
# men_means = [20, 34, 30, 35]
# women_means = [25, 32, 34, 20]

x = np.arange(len(labels))  # the label locations
# width = 0.35  # the width of the bars

rects = [0 for i in range(2 * len(label_arr))]
fig, ax = plt.subplots()
for i in range(len(label_arr)):
#     rects[i] = ax.plot(normal_arr[i], label=label_arr[i] + ' Benign')
#     rects[len(label_arr) +  i] = ax.plot(attack_arr[i], label=label_arr[i] + ' Adv',linestyle = (0, (1, 10)))
    rects[i] = ax.plot(normal_arr[i])
    rects[len(label_arr) +  i] = ax.plot(attack_arr[i], linestyle = (0, (1, 1)))
# rects[1] = ax.plot(men_means, label='Men')
# rects[2] = ax.plot(women_means, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Fingerprint per Device',fontsize = 16)
# ax.set_title('Scores by group and gender')
ax.set_xticks(x, labels,fontsize = 16)
# ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.savefig('Division_time_ua.eps',format='eps')
plt.show()
