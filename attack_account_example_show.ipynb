# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import csv
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from matplotlib import gridspec



import csv
import pandas as pd
import sys
import time

# %%
'''
The file is like

'_id', '_timestamp', 'bfp', 'ip', 'asn', 'tel_accountName', 'shapeCookie', 'ua', 'tel_attackCause', 'flowLabel'

'''

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
bfp_dic = {}
acc_dic = {}
for raw_data in reader_lines:
    print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    bfp = raw_data[2]
    acc = raw_data[5]
    if bfp not in bfp_dic:
        bfp_dic[bfp] = {}
    if acc not in bfp_dic[bfp]:
        bfp_dic[bfp][acc] = 1
    else:
        bfp_dic[bfp][acc] += 1

# %%
bfp_dic

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
bfp_dic = {}
acc_dic = {}
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    bfp = raw_data[2]
    acc = raw_data[5]
    if bfp not in bfp_dic:
        bfp_dic[bfp] = 1
    else:
        bfp_dic[bfp] += 1

# %%
bfp_dic = dict(sorted(bfp_dic.items(),key = lambda i:i[1], reverse = -1 ))
bfp_dic

# %%
# After we analyze, we find some account. We didn't show the analysis code
target_acc = ['a','b','c','d']

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
bfp_dic = {}
acc_dic = {}
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    bfp = raw_data[2]
    acc = raw_data[5]
    if acc in target_acc:
#         print(1)
        continue
    if bfp not in bfp_dic:
        bfp_dic[bfp] = [1,1,{acc}]
    else:
        bfp_dic[bfp][0] += 1
        if acc not in bfp_dic[bfp][2]:
            bfp_dic[bfp][1] += 1
            bfp_dic[bfp][2].add(acc)

# %%
bfp_dic = dict(sorted(bfp_dic.items(),key = lambda i:i[1], reverse = -1 ))
len(bfp_dic)

# %%
bfp_accnumber = []
for key in bfp_dic:
    bfp_accnumber.append(bfp_dic[key][1])
# bfp_accnumber
dis_bfp_accnumber = [0] * 11
for ele in bfp_accnumber:
    if ele >= 10:
        dis_bfp_accnumber[10] += 1
    else:
        dis_bfp_accnumber[ele] += 1
s = sum(dis_bfp_accnumber)
for i in range(len(dis_bfp_accnumber)):
    dis_bfp_accnumber[i] = dis_bfp_accnumber[i] / s * 100
dis_bfp_accnumber[1:]

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
acc_dic = {}
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    
    bfp = raw_data[2]
    acc = raw_data[5]
    if acc in target_acc:
        continue
        
    if acc not in acc_dic:
        acc_dic[acc] = [1,{}]
    else:
        acc_dic[acc][0] += 1
    if bfp not in acc_dic[acc][1]:
        acc_dic[acc][1][bfp] = 1
    else:
        acc_dic[acc][1][bfp] += 1

# %%
acc_dic = dict(sorted(acc_dic.items(),key = lambda i:i[1][0], reverse = -1 ))
len(acc_dic)

# %%
acc_bfpnum = []
for key in acc_dic:
    acc_bfpnum.append(len(acc_dic[key][1]))
dis_acc_bfpnum = [0] * 11
for ele in acc_bfpnum:
    if ele >= 10:
        dis_acc_bfpnum[10] += 1
    else:
        dis_acc_bfpnum[ele] += 1
s = sum(dis_acc_bfpnum)
for i in range(len(dis_acc_bfpnum)):
    dis_acc_bfpnum[i] = dis_acc_bfpnum[i] / s * 100
dis_acc_bfpnum[1:]

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
detect = 0
target = 0
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    acc = raw_data[5]
    if acc in target_acc:
        detect += 1
    else:
        target += 1
    
print(detect)
print(target)

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
bfpDic = {}
dateDic = {}
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    bfp = raw_data[2]
    acc = raw_data[5]
    # We remove the name
    if acc == 'demo':
        
        date = raw_data[1].split('T')[0]
        print(date,bfp,raw_data[3])
        if bfp not in bfpDic:
            bfpDic[bfp] = 1
        else:
            bfpDic[bfp] += 1
        if date not in dateDic:
            dateDic[date] = 1
        else:
            dateDic[date] += 1
print(bfpDic)
print(dateDic)

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
bfpDic = set()
dateDic = set()
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    acc = raw_data[5]
    date = raw_data[1].split('T')[0]
    if acc in target_acc:
        bfpDic.add(date)
    else:
        dateDic.add(date)
print(len(bfpDic))
print(len(dateDic))

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
bfpDic = {}
dateDic = {}
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    bfp = raw_data[2]
    acc = raw_data[5]
    if acc == 'demo':
        
        date = raw_data[1].split('T')[0]
        if bfp not in bfpDic:
            bfpDic[bfp] = 1
        else:
            bfpDic[bfp] += 1
        if date not in dateDic:
            dateDic[date] = 1
        else:
            dateDic[date] += 1
print(bfpDic)
print(dateDic)

# %%
# analyze each feather changed
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
fea = [{}, {},{},{},{},{}]
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    bfp = raw_data[2].split('-')
    for i in range(1,7):
        if bfp[i] not in fea[i - 1]:
            fea[i - 1][bfp[i]] = 1
        else:
            fea[i - 1][bfp[i]] += 1
fea

# %%
#date
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
date_dic = {}
for raw_data in reader_lines:
#     print(raw_data)
    if len(raw_data[0]) < 5:
        continue
    date = raw_data[1]
    date = date.split('T')[0]
    bfp = raw_data[2]
    acc = raw_data[5]
#   traffic_num, bfp_num, acc_num

    if date not in date_dic:
        date_dic[date] = [1,1,1,{bfp},{acc}]
    else:
        date_dic[date][0] += 1
        if bfp not in date_dic[date][3]:
            date_dic[date][1] += 1
            date_dic[date][3].add(bfp)
        if acc not in date_dic[date][4]:
            date_dic[date][2] += 1
            date_dic[date][4].add(acc)

# %%
datearr = []
tra = []
bfp = []
acc = []
for key in date_dic:
    datearr.append(key)
    tra.append(date_dic[key][0])
    bfp.append(date_dic[key][1])
    acc.append(date_dic[key][2])
    print(key, date_dic[key][:3])

# %%
datearr = datearr[::-1]
tra = tra[::-1]
bfp = bfp[::-1]
acc = acc[::-1]
datearr

# %%
new_date = []
for ele in datearr:
    new_date.append(ele[5:])
datearr = new_date
rate = []
tra_acc = []
for i in range(len(bfp)):
    rate.append(acc[i]/bfp[i])
    tra_acc.append(tra[i]/acc[i])

# %%
'''
This is the different account attack by date
in this example
acc1: 
11-23: 417
11-14: 106
acc2:
11-15: 353
acc3:
11-23: 179
11-22: 57
11-19: 82
11-17: 120
11-14: 84
acc4:
11-22: 219
11-20: 83
acc5:
12-02: 63
11-29: 64
acc6:
12-01: 223
acc7:
11-17: 114
'''

# %%
plt.rcParams.update({'font.size':12})
fig, axs = plt.subplots(4, 1, sharex=True,figsize=(16,6))
# Remove horizontal space between axes
fig.subplots_adjust(hspace=0)
# print(len(pro_acc))

width = 0.60       # the width of the bars: can also be len(x) sequence

line1 = axs[0].plot(date, target_old_acc,marker = 'o',label='Target Old Account')
line2 = axs[0].plot(date, target_new_acc,marker = 'v',label='Target New Account')
line3 = axs[1].plot(date, target_old_bfp,marker = 's',label='Target Old Fingerprint')
line4 = axs[1].plot(date, target_new_bfp,marker = '*',label='Target New Fingerprint')

line3 = axs[2].plot(date, target_tra,'o-',label='Target Request')
line4 = axs[2].plot(date, pro_tra,'x-',label='Probe Request')

line5 = axs[3].plot(date, pro_acc,'x-',label='Probe Account')


# axs[2].bar(datearr, rate, width)
axs[0].legend()
axs[1].legend()
axs[2].legend()
axs[3].legend()
plt.xticks(rotation=-45)

# %%
file = open('./demo.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
dic = {}
for raw_data in reader_lines:
    if len(raw_data[0]) < 5:
        continue
    date = raw_data[1]
    date = date.split('T')[0]
    bfp = raw_data[2]
    acc = raw_data[5]
    if acc not in dic:
        dic[acc] = {}
    if bfp not in dic[acc]:
        dic[acc][bfp] = [date[5:]]
    if date[5:] not in dic[acc][bfp]:
        dic[acc][bfp].append(date[5:])
tem = 0
for ele in dic:
    if len(dic[ele]) == 1:
        tem += 1
print(tem/len(dic))
