# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import csv
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
from matplotlib import gridspec
import csv
import pandas as pd
import sys
import time

# %%
# Dataset struction
'''
company name
a 0
b 1
c 2
d  3
e 4
f 5
g 6
h 7
i 8
j 9
k 10
l 11
m 12
n 13

folder name 
screenFeature 0
pluginFeature 1
dateFeature 2
browserFeature 3
canvasFeature 4
fontsFeature 5
browser + os  6
verndor+renderer 7
6 + 7     8
city+region     9
devicePixelRatio 10
screem(same with 0) 11

The path:
bfp/ + featurename + companyname + A(attack)/N(normal)
In each file .csv
raw_data rate(of the whole number)

'''

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
# print(feature)
UA = '6'
n = len(company)
bfp_sum = {}
attack_tool = set()
flag= ['Windows', 'Mac','iOS', 'Linux','Ubuntu',"Android","Chrome","Safari","Firefox"]
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
    print(company[i], '=================================')
    print('Attack===============================')
    for raw_data in attack_reader_lines:
        if any(word in raw_data[0] for word in flag):
            continue
        if len(raw_data[0]) < 2:
            continue
        attack_tool.add(raw_data[0])
print(attack_tool)

# %%
for ele in attack_tool:
    if 'py' in ele:
        print(ele)

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
UA = '6'
n = len(company)
bfp_sum = {}
attack_tool = set()
flag= ['Windows', 'Mac','iOS', 'Linux','Ubuntu',"Android","Chrome","Safari","Firefox"]
python = ['Py', 'py']
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
    for raw_data in attack_reader_lines:
        if any(word in raw_data[0] for word in python):
            attack_tool.add(raw_data[0])
attack_tool

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
# print(feature)
UA = '6'
n = len(company)
bfp_sum = {}
attack_tool = set()
java = ['Ja', 'ja']
flag= ['Windows', 'Mac','iOS', 'Linux','Ubuntu',"Android","Chrome","Safari","Firefox"]
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
    for raw_data in attack_reader_lines:
        if any(word in raw_data[0] for word in java):
            attack_tool.add(raw_data[0])
attack_tool

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
# print(feature)
UA = '6'
n = len(company)
bfp_sum = {}
attack_tool = set()
flag= ['Windows', 'Mac','iOS', 'Linux','Ubuntu',"Android","Chrome","Safari","Firefox"]
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
    print(company[i], '=================================')
    print('Attack===============================')
    for raw_data in attack_reader_lines:
        if 'ja' in raw_data[0]:
            print(raw_data[0])

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
# print(feature)
UA = '6'
n = len(company)
bfp_sum = {}
attack_tool = set()
flag= ['Windows', 'Mac','iOS', 'Linux','Ubuntu',"Android","Chrome","Safari","Firefox"]
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
#     print(company[i], '=================================')
#     print('Attack===============================')
    for raw_data in attack_reader_lines:
        if 'bot' in raw_data[0]:
            attack_tool.add(raw_data[0])
attack_tool

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
# print(feature)
UA = '6'
n = len(company)
bfp_sum = {}
attack_tool = set()
flag= ['Windows', 'Mac','iOS', 'Linux','Ubuntu',"Android","Chrome","Safari","Firefox"]
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
    print(company[i], '=================================')
    print('Attack===============================')
    for raw_data in attack_reader_lines:
        if 'cra' in raw_data[0]:
            print(raw_data[0])

# %%
# This sub library bot
# We can not show all of them

library_framework = ["Python Requests","Python-urllib","pyspider","Java","ONBbot","WEBbot","dwbot","net/bot",
                    "facebookscraper","MetadataScraper"]
open_source_project = ["Scrapy","Jasmine","NinjaBot","jambot","TSMbot","ethical-bugbot","BLP_bbot","yacybot","linkbot"
                       ,"CrowdTanglebot","Discordbot","Elisabot","Facebot","Fyrebot","Gigabot","I-am-a-bot","Info bot",
                      "Infosecbot","Magnetbot","Mediumbot","Primalbot","Refindbot","Riverbot","Rustbot","Semanticbot",
                      "Superfeedr bot","TinEye-bot","culturebot","yaanibot","Dragonbot","Check-sitecrawl","SimpleScraper",
                      "node-crawler","cis455crawler","dcrawl","crawler4j","Testcrawler","dev-cocrawler","SIDEARM Sports Content Scraper",
                      "pwa-crawler"]
free_bot = ["SiteAnalyzerbot","rogerbot"]
commercial_bot = ["Cocolyzebot","Googlebot","com/bot","Gentooyacybot","Exabot","Storebot","Applebot","moatbot","Adsbot"
                 ,"Anewsbot","Checkbot","Gowikibot","HatenaBlog-bot","MJ12bot","Mediatoolkitbot","Monsidobot",
                 "Pinterestbot","Quantcastbot","Slackbot","Snapbot","Taboolabot","ripleCheckerRobot","Twitterbot",
                 "Yelpbot","alexa verifybot","archive.org_bot","bingadsbot","bingbot","bitlybot","chimebot",
                 "coccocbot","com feedbot","domainsbot","fuelbot","houzzbot","io_bot","linkdexbot","lyticsbot",
                 "media-bot","mediacloud bot","msnbot","notebot","online-webceo-bot","redditbot","sc_bot","seo-audit-check-bot",
                 "serpstatbot","url robot","zoominfobot","Cookiebot","Altmetribot","rc-crawler","QuiqScrapeBot",
                 "pagefreezer crawler","sitecrawler","rapidminer-web-mining-extension-crawler"]
private_bot = ["ChirpyHubBot","wq2bot07","GnowitNewsbot","zbot","Atomseobot","Deskyobot","FindITAnswersbot","Jones Searchbot",
              "Konturbot","Lawinsiderbot","MTRobot","Miralinks Robot","Mojoo Robot","Nesotebot","Ocarinabot",
              "Ranking Gentle bot","Sidetrade indexer bot","UnusedCSS_bot","Yellowbrandprotectionbot", "asset-caching-bot",
              "compatible; botify","contxbot","startmebot","www.botje","xintellibot","BDCbot","superpagesbot2",
              "naverbookmarkcrawler","test-deep-cocrawler","crawler_eb_germany_2"]
other = ["- This bot", "//bot", "8080/bot","; bot", "Dy robot","K4U-Spider (bot","Onefuncbot","OpenGraph Robot"
        ,"POPSUGAR Shopping bot","Search engine bot", "Social Embed bot","com robot","doc/botinfo","metadata-downloader-bot"
         ,"perrfy-bot","uipbot","vebidoobot","qbotvv6pu6","SVBr57cX7lvR1TWeVmIbotk","kwznbot7","lfbotlg35j4","xs-SPbotCpRfEw",
        "4.0 obot","crawler","crawlingpolicy","human-crawl_ui","com crawler",]

# %%
file = open('./sum.csv','r',newline='')
reader_lines = csv.reader(x.replace('\0', '') for x in file)
i = 0
for raw_data in reader_lines:
    print(i)
    if i == 0:
        attack_array = raw_data
        print(attack_array)
    if i == 1:
        normal_array = raw_data
    i += 1

# %%
num_company = 14
num = 12
company = ['a','b','c','d','e','f','g','h','i','j','k','l','m','n']
feature = ['screenFeature','pluginFeature','dateFeature','browserFeature','canvasFeature','fontsFeature','browser+os','verndor+renderer','browser+os+verndor+renderer ','city+region','devicePixelRatio','screensize']
# print(feature)
UA = '6'
n = len(company)
result_traffic = [0,0,0,0,0,0]
for i in range(n):
    attck_file = open('../bfp/' +UA+ '/' + str(i) +'A.csv','r',newline='')
    normal_file = open('../bfp/' + UA+ '/'+ str(i) +'N.csv','r',newline='')
    attack_reader_lines = csv.reader(x.replace('\0', '') for x in attck_file)
    normal_reader_lines = csv.reader(x.replace('\0', '') for x in normal_file)
    for raw_data in attack_reader_lines:
        if any(word in raw_data[0] for word in library_framework):
            result_traffic[0] += float(raw_data[1]) * float(attack_array[i])
        elif any(word in raw_data[0] for word in open_source_project):
            result_traffic[1] += float(raw_data[1]) * float(attack_array[i])
        elif any(word in raw_data[0] for word in free_bot):
            result_traffic[2] += float(raw_data[1]) * float(attack_array[i])
        elif any(word in raw_data[0] for word in commercial_bot):
            result_traffic[3] += float(raw_data[1]) * float(attack_array[i])
        elif any(word in raw_data[0] for word in private_bot):
            result_traffic[4] += float(raw_data[1]) * float(attack_array[i])
        elif any(word in raw_data[0] for word in other):
            result_traffic[5] += float(raw_data[1]) * float(attack_array[i])
print(result_traffic)
s = sum(result_traffic)
for ele in result_traffic:
    print(ele / s)
